# %%
import pandas as pd

# %% [raw]
# import matplotib.pyplot as plt

# %%
pd.read_csv('Pollution Rate.csv')
# Out:
#               Entity      Code  Year  Total population (Gapminder, HYDE & UN)  \
# 0           Abkhazia  OWID_ABK  2015                                      NaN
# 1        Afghanistan       AFG  1800                                3280000.0
# 2        Afghanistan       AFG  1801                                3280000.0
# 3        Afghanistan       AFG  1802                                3280000.0
# 4        Afghanistan       AFG  1803                                3280000.0
# ...              ...       ...   ...                                      ...
# 49025       Zimbabwe       ZWE  2016                               14030000.0
# 49026       Zimbabwe       ZWE  2017                               14237000.0
# 49027       Zimbabwe       ZWE  2018                               14439000.0
# 49028       Zimbabwe       ZWE  2019                               14645000.0
# 49029  Åland Islands       ALA  2015                                      NaN
#
# ...

# %%
df_population_raw=pd.read_csv('Pollution Rate.csv')

# %%
df_population_raw
# Out:
#               Entity      Code  Year  Total population (Gapminder, HYDE & UN)  \
# 0           Abkhazia  OWID_ABK  2015                                      NaN
# 1        Afghanistan       AFG  1800                                3280000.0
# 2        Afghanistan       AFG  1801                                3280000.0
# 3        Afghanistan       AFG  1802                                3280000.0
# 4        Afghanistan       AFG  1803                                3280000.0
# ...              ...       ...   ...                                      ...
# 49025       Zimbabwe       ZWE  2016                               14030000.0
# 49026       Zimbabwe       ZWE  2017                               14237000.0
# 49027       Zimbabwe       ZWE  2018                               14439000.0
# 49028       Zimbabwe       ZWE  2019                               14645000.0
# 49029  Åland Islands       ALA  2015                                      NaN
#
# ...

# %%
df_population_raw.dropna(inplace=True)

# %%
df_pivot=df_population_raw.pivot(index='Year', columns='Entity',values='Total population (Gapminder, HYDE & UN)')

# %%
df_pivot
# Out:
# Entity  Afghanistan    Albania     Algeria      Angola  Antigua and Barbuda  \
# Year
# 2015     34414000.0  2891000.0  39728000.0  27884000.0              94000.0
#
# Entity   Argentina    Armenia   Australia    Austria  Azerbaijan  ...  \
# Year                                                              ...
# 2015    43075000.0  2926000.0  23932000.0  8679000.0   9623000.0  ...
#
# Entity  United Arab Emirates  United Kingdom  United States    Uruguay  \
# Year
# 2015               9263000.0      65860000.0    320878016.0  3412000.0
#
# Entity  Uzbekistan   Vanuatu     Vietnam       Yemen      Zambia    Zimbabwe
# Year
# 2015    30930000.0  271000.0  92677000.0  26498000.0  15879000.0  13815000.0
#
# [1 rows x 180 columns]

# %%
df_pivot=df_pivot[['Afghanistan','Vietnam','Zimbabwe']]

# %%
df_pivot.plot(kind='line',xlabel='Year',ylabel='Total population (Gapminder, HYDE & UN)',figsize=(8,4))
# Out:
# <Axes: xlabel='Year', ylabel='Total population (Gapminder, HYDE & UN)'>

# %%
plt.show()

# %%
df_pivot.to_excel('pivot_table.xlsx',index=False, engine="openpyxl")
